# %%
import cv2

# %%
img = cv2.imread('sample_pic.jpg')

newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()
plt.imshow(newImg)
plt.show()

# %%
img = cv2.imread('sample_pic.jpg')
gray = cv2.imread('sample_pic.jpg',cv2.IMREAD_GRAYSCALE)

# %%
cv2.imshow("Sample",img)
cv2.imshow("Sample2",gray)
